# %%
import sqlite3
conn = sqlite3.connect("Chinook_Sqlite.sqlite")
cursor = conn.cursor()

# %% [markdown]
# # 1 Basic SQL Queries

# %% [markdown]
# ## (a)

# %%
invoices = cursor.execute('SELECT InvoiceID, CustomerID FROM Invoice ORDER BY Total DESC LIMIT 15')
for row in invoices:
    print(row)
# Out:
# (404, 6)
# (299, 26)
# (96, 45)
# (194, 46)
# (89, 7)
# (201, 25)
# (88, 57)
# (306, 5)
# (313, 43)
# (103, 24)
# (208, 4)
# (193, 37)
# (5, 23)
# (12, 2)
# (19, 40)

# %% [markdown]
# ## (b)

# %%
first_names = cursor.execute('SELECT Employee.FirstName,Employee.LastName FROM Employee,Customer WHERE Employee.FirstName == Customer.FirstName')
for row in first_names:
    print(row)
# Out:
# ('Steve', 'Johnson')
# ('Robert', 'King')

# %% [markdown]
# ## (c)

# %%
last_names = cursor.execute('SELECT Employee.FirstName,Employee.LastName FROM Employee,Customer WHERE Employee.LastName == Customer.LastName')
for row in last_names:
    print(row)
# Out:
# ('Michael', 'Mitchell')

# %% [markdown]
# ## (d)

# %%
cursor.execute('SELECT g.Name,COUNT(*) FROM Track t, Genre g ON g.GenreID == t.GenreID GROUP BY g.GenreID ORDER BY COUNT(*) DESC')
output = cursor.fetchall();
print(output[0][0])
# for row in output:
#     print(row)
# Out:
# Rock

# %% [markdown]
# ## (e)

# %%
cursor.execute('SELECT FirstName, LastName,COUNT(TrackId)\
               FROM \
               (SELECT c.FirstName,c.LastName,c.CustomerId, t.TrackId FROM Customer c\
               INNER JOIN Invoice i ON c.CustomerId == i.InvoiceId\
               INNER JOIN InvoiceLine il ON i.InvoiceId == il.InvoiceId\
               INNER JOIN Track t ON il.TrackId == t.TrackId)\
               GROUP BY CustomerId\
               ORDER BY COUNT(TrackId) DESC')
output = cursor.fetchall()
num = output[0][2]
for row in output:
    if(row[2] == num):
        print(row[:2])
# Out:
# ('František', 'Wichterlová')
# ('Roberto', 'Almeida')
# ('Tim', 'Goyer')
# ('Richard', 'Cunningham')
# ('Ellie', 'Sullivan')
# ('Dominique', 'Lefebvre')
# ('Lucas', 'Mancini')
# ('Steve', 'Murray')

# %% [markdown]
# ## (f)

# %%
cursor.execute("""
                SELECT Name, Cnt
                FROM
                   (
                   SELECT Name,COUNT(AlbumId) AS Cnt
                       FROM 
                       (
                       SELECT Artist.Name, Album.AlbumId FROM Artist
                       INNER JOIN Album USING (ArtistId)
                       )
                   GROUP BY Name
                   )
               WHERE Cnt > 5
               """)
Qf = cursor.fetchall()
for row in Qf:
    print(row)
# Out:
# ('Deep Purple', 11)
# ('Iron Maiden', 21)
# ('Led Zeppelin', 14)
# ('Metallica', 10)
# ('Ozzy Osbourne', 6)
# ('U2', 10)

# %% [markdown]
# ## (g)

# %%
cursor.execute("""
                SELECT DISTINCT Artist, Genre
                FROM
                   (
                   SELECT ar.Name AS Artist, g.Name AS Genre 
                   FROM Artist ar 
                   INNER JOIN Album al ON ar.ArtistId == al.ArtistId
                   INNER JOIN Track t ON al.AlbumId == t.AlbumId
                   INNER JOIN Genre g ON t.GenreId == g.GenreId
                   )
                WHERE Artist == 'Iron Maiden'
               """)
Qg = cursor.fetchall()
for row in Qg:
    print(row)
# Out:
# ('Iron Maiden', 'Rock')
# ('Iron Maiden', 'Metal')
# ('Iron Maiden', 'Heavy Metal')
# ('Iron Maiden', 'Blues')

# %% [markdown]
# ## (h)

# %%
cursor.execute("""
                SELECT Title,Cnt
                FROM
                (
                    SELECT Title,COUNT(DISTINCT PlaylistId) AS Cnt
                    FROM
                       (
                       SELECT a.Title, p.PlaylistId
                       FROM Album a
                       INNER JOIN Track t ON a.AlbumId == t.AlbumId
                       INNER JOIN PlaylistTrack pl ON t.TrackId == pl.TrackId
                       INNER JOIN Playlist p ON p.PlaylistId == pl.PlaylistId
                       )
                    GROUP BY Title
                )
                WHERE Cnt > 3
                """)
Qh = cursor.fetchall()
for row in Qh:
    print(row)
# Out:
# ('A Copland Celebration, Vol. I', 4)
# ('A Soprano Inspired', 5)
# ('A-Sides', 4)
# ('Adams, John: The Chairman Dances', 4)
# ('Adorate Deum: Gregorian Chant from the Proper of the Mass', 5)
# ('Allegri: Miserere', 5)
# ('Armada: Music from the Courts of England and Spain', 4)
# ('Bach: Goldberg Variations', 5)
# ('Bach: Orchestral Suites Nos. 1 - 4', 5)
# ('Bach: The Brandenburg Concertos', 4)
# ('Bach: The Cello Suites', 5)
# ('Bach: Toccata & Fugue in D Minor', 5)
# ('Bach: Violin Concertos', 4)
# ('Bartok: Violin & Viola Concertos', 4)
# ('Beethoven Piano Sonatas: Moonlight & Pastorale', 5)
# ('Beethoven: Symhonies Nos. 5 & 6', 5)
# ("Beethoven: Symphony No. 6 'Pastoral' Etc.", 4)
# ('Berlioz: Symphonie Fantastique', 5)
# ('Bizet: Carmen Highlights', 5)
# ('Black Album', 4)
# ('Carmina Burana', 5)
# ('Charpentier: Divertissements, Airs & Concerts', 4)
# ('Chopin: Piano Concertos Nos. 1 & 2', 5)
# ('Core', 4)
# ('Djavan Ao Vivo - Vol. 02', 4)
# ('Djavan Ao Vivo - Vol. 1', 4)
# ('Elgar: Cello Concerto & Vaughan Williams: Fantasias', 4)
# ('English Renaissance', 6)
# ('Facelift', 4)
# ('Fauré: Requiem, Ravel: Pavane & Others', 4)
# ('Great Opera Choruses', 5)
# ("Great Performances - Barber's Adagio and Other Romantic Favorites for Strings", 4)
# ('Great Recordings of the Century - Mahler: Das Lied von der Erde', 5)
# ('Great Recordings of the Century - Shubert: Schwanengesang, 4 Lieder', 4)
# ("Great Recordings of the Century: Paganini's 24 Caprices", 4)
# ('Grieg: Peer Gynt Suites & Sibelius: Pelléas et Mélisande', 4)
# ('Górecki: Symphony No. 3', 5)
# ('Handel: Music for the Royal Fireworks (Original Version 1749)', 5)
# ('Handel: The Messiah (Highlights)', 5)
# ('Haydn: Symphonies 99 - 104', 4)
# ('Holst: The Planets, Op. 32 & Vaughan Williams: Fantasies', 5)
# ('J.S. Bach: Chaconne, Suite in E Minor, Partita in E Major & Prelude, Fugue and Allegro', 5)
# ('Koyaanisqatsi (Soundtrack from the Motion Picture)', 5)
# ("Liszt - 12 Études D'Execution Transcendante", 4)
# ('Locatelli: Concertos for Violin, Strings and Continuo, Vol. 3', 5)
# ('Mascagni: Cavalleria Rusticana', 5)
# ("Mendelssohn: A Midsummer Night's Dream", 5)
# ('Meus Momentos', 4)
# ('Minha Historia', 4)
# ("Monteverdi: L'Orfeo", 4)
# ('Motley Crue Greatest Hits', 4)
# ('Mozart Gala: Famous Arias', 5)
# ('Mozart: Chamber Music', 4)
# ('Mozart: Symphonies Nos. 40 & 41', 5)
# ('Mozart: Wind Concertos', 4)
# ('Nevermind', 4)
# ('Nielsen: The Six Symphonies', 4)
# ('Pachelbel: Canon & Gigue', 4)
# ('Palestrina: Missa Papae Marcelli & Allegri: Miserere', 4)
# ("Pavarotti's Opera Made Easy", 5)
# ('Prenda Minha', 4)
# ('Prokofiev: Romeo & Juliet', 5)
# ('Prokofiev: Symphony No.1', 4)
# ('Prokofiev: Symphony No.5 & Stravinksy: Le Sacre Du Printemps', 4)
# ('Puccini: Madama Butterfly - Highlights', 4)
# ('Purcell: Music for the Queen Mary', 4)
# ('Purcell: The Fairy Queen', 4)
# ('Quanta Gente Veio Ver (Live)', 4)
# ('Respighi:Pines of Rome', 5)
# ('Restless and Wild', 4)
# ('SCRIABIN: Vers la flamme', 4)
# ('Scheherazade', 5)
# ("Schubert: The Late String Quartets & String Quintet (3 CD's)", 4)
# ('Sibelius: Finlandia', 5)
# ('Sir Neville Marriner: A Celebration', 4)
# ('South American Getaway', 4)
# ('Strauss: Waltzes', 5)
# ('Szymanowski: Piano Works, Vol. 1', 5)
# ("Tchaikovsky: 1812 Festival Overture, Op.49, Capriccio Italien & Beethoven: Wellington's Victory", 5)
# ('Tchaikovsky: The Nutcracker', 4)
# ('Temple of the Dog', 4)
# ('Ten', 4)
# ('The Last Night of the Proms', 5)
# ('The Ultimate Relexation Album', 4)
# ('The World of Classical Favourites', 6)
# ('Unplugged', 4)
# ('Vivaldi: The Four Seasons', 4)
# ('Vs.', 4)
# ('Wagner: Favourite Overtures', 5)
# ('Weill: The Seven Deadly Sins', 5)

# %% [markdown]
# # 2 Clustering Artists

# %% [markdown]
# ## (a)

# %%
import pandas as pd

# %%
cursor.execute("""
                SELECT ar.Name AS Artist, al.Title AS Album, g.Name AS Genre, p.Name AS Playlist, t.Name AS Track
                FROM Artist ar
                INNER JOIN Album al ON ar.ArtistId == al.ArtistId
                INNER JOIN Track t ON t.AlbumId == al.AlbumId
                INNER JOIN Genre g ON g.GenreId == t.GenreId
                INNER JOIN PlaylistTrack pt ON t.TrackId == pt.TrackId
                INNER JOIN Playlist p ON p.PlaylistId == PT.PlaylistId
               """)
output = cursor.fetchall()
for row in output:
    print(row)
# Out:
# ('Audioslave', 'Revelations', 'Alternative', 'Music', 'Band Members Discuss Tracks from "Revelations"')
# ('Audioslave', 'Revelations', 'Alternative', 'Music', 'Revelations')
# ('Audioslave', 'Revelations', 'Alternative', 'Music', 'One and the Same')
# ('Audioslave', 'Revelations', 'Alternative', 'Music', 'Sound of a Gun')
# ('Audioslave', 'Revelations', 'Alternative', 'Music', 'Until We Fall')
# ('Audioslave', 'Revelations', 'Alternative', 'Music', 'Original Fire')
# ('Audioslave', 'Revelations', 'Alternative', 'Music', 'Broken City')
# ('Audioslave', 'Revelations', 'Alternative', 'Music', 'Somedays')
# ('Audioslave', 'Revelations', 'Alternative', 'Music', 'Shape of Things to Come')
# ('Audioslave', 'Revelations', 'Alternative', 'Music', 'Jewel of the Summertime')
# ('Audioslave', 'Revelations', 'Alternative', 'Music', 'Wide Awake')
# ('Audioslave', 'Revelations', 'Alternative', 'Music', 'Nothing Left to Say But Goodbye')
# ('Audioslave', 'Revelations', 'Alternative', 'Music', 'Moth')
# ('Audioslave', 'Revelations', 'Alternative', 'Music', 'Show Me How to Live (Live at the Quart Festival)')
# ('Cake', 'Cake: B-Sides and Rarities', 'Alternative', 'Music', 'War Pigs')
# ('Calexico', 'Carried to Dust (Bonus Track Version)', 'Alternative', 'Music', 'Slowness')
# ('Chris Cornell', 'Carry On', 'Alternative', 'Music', 'No Such Thing')
# ('Chris Cornell', 'Carry On', 'Alternative', 'Music', 'Poison Eye')
# ('Chris Cornell', 'Carry On', 'Alternative', 'Music', 'Arms Around Your Love')
# ('Chris Cornell', 'Carry On', 'Alternative', 'Music', 'Safe and Sound')
# ('Chris Cornell', 'Carry On', 'Alternative', 'Music', "She'll Never Be Your Man")
# ('Chris Cornell', 'Carry On', 'Alternative', 'Music', 'Ghosts')
# ('Chris Cornell', 'Carry On', 'Alternative', 'Music', 'Killing Birds')
# ('Chris Cornell', 'Carry On', 'Alternative', 'Music', 'Billie Jean')
# ('Chris Cornell', 'Carry On', 'Alternative', 'Music', 'Scar On the Sky')
# ('Chris Cornell', 'Carry On', 'Alternative', 'Music', 'Your Soul Today')
# ('Chris Cornell', 'Carry On', 'Alternative', 'Music', 'Finally Forever')
# ('Chris Cornell', 'Carry On', 'Alternative', 'Music', 'Silence the Voices')
# ('Chris Cornell', 'Carry On', 'Alternative', 'Music', 'Disappearing Act')
# ('Chris Cornell', 'Carry On', 'Alternative', 'Music', 'You Know My Name')
# ('Temple of the Dog', 'Temple of the Dog', 'Alternative', 'Music', 'Say Hello 2 Heaven')
# ('Temple of the Dog', 'Temple of the Dog', 'Alternative', 'Music', 'Reach Down')
# ('Temple of the Dog', 'Temple of the Dog', 'Alternative', 'Music', 'Hunger Strike')
# ('Temple of the Dog', 'Temple of the Dog', 'Alternative', 'Music', 'Pushin Forward Back')
# ('Temple of the Dog', 'Temple of the Dog', 'Alternative', 'Music', 'Call Me a Dog')
# ('Temple of the Dog', 'Temple of the Dog', 'Alternative', 'Music', 'Times of Trouble')
# ('Temple of the Dog', 'Temple of the Dog', 'Alternative', 'Music', 'Wooden Jesus')
# ('Temple of the Dog', 'Temple of the Dog', 'Alternative', 'Music', 'Your Savior')
# ('Temple of the Dog', 'Temple of the Dog', 'Alternative', 'Music', 'Four Walled World')
# ('Temple of the Dog', 'Temple of the Dog', 'Alternative', 'Music', 'All Night Thing')
# ('Audioslave', 'Out Of Exile', 'Alternative & Punk', 'Music', 'Your Time Has Come')
# ('Audioslave', 'Out Of Exile', 'Alternative & Punk', 'Music', 'Out Of Exile')
# ('Audioslave', 'Out Of Exile', 'Alternative & Punk', 'Music', 'Be Yourself')
# ('Audioslave', 'Out Of Exile', 'Alternative & Punk', 'Music', "Doesn't Remind Me")
# ('Audioslave', 'Out Of Exile', 'Alternative & Punk', 'Music', 'Drown Me Slowly')
# ('Audioslave', 'Out Of Exile', 'Alternative & Punk', 'Music', "Heaven's Dead")
# ('Audioslave', 'Out Of Exile', 'Alternative & Punk', 'Music', 'The Worm')
# ('Audioslave', 'Out Of Exile', 'Alternative & Punk', 'Music', 'Man Or Animal')
# ('Audioslave', 'Out Of Exile', 'Alternative & Punk', 'Music', 'Yesterday To Tomorrow')
# ('Audioslave', 'Out Of Exile', 'Alternative & Punk', 'Music', 'Dandelion')
# ('Audioslave', 'Out Of Exile', 'Alternative & Punk', 'Music', '#1 Zero')
# ('Audioslave', 'Out Of Exile', 'Alternative & Punk', 'Music', 'The Curse')
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', 'Smoked Pork')
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', "Body Count's In The House")
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', 'Now Sports')
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', 'Body Count')
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', 'A Statistic')
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', 'Bowels Of The Devil')
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', 'The Real Problem')
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', 'KKK Bitch')
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', 'D Note')
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', 'Voodoo')
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', 'The Winner Loses')
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', 'There Goes The Neighborhood')
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', 'Oprah')
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', 'Evil Dick')
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', 'Body Count Anthem')
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', "Momma's Gotta Die Tonight")
# ('Body Count', 'Body Count', 'Alternative & Punk', 'Music', 'Freedom Of Speech')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'White Riot')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'Remote Control')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'Complete Control')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'Clash City Rockers')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', '(White Man) In Hammersmith Palais')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'Tommy Gun')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'English Civil War')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'I Fought The Law')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'London Calling')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'Train In Vain')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'Bankrobber')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'The Call Up')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'Hitsville UK')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'The Magnificent Seven')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'This Is Radio Clash')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'Know Your Rights')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'Rock The Casbah')
# ('The Clash', 'The Singles', 'Alternative & Punk', 'Music', 'Should I Stay Or Should I Go')
# ('Faith No More', 'Album Of The Year', 'Alternative & Punk', 'Music', 'Collision')
# ('Faith No More', 'Album Of The Year', 'Alternative & Punk', 'Music', 'Stripsearch')
# ('Faith No More', 'Album Of The Year', 'Alternative & Punk', 'Music', 'Last Cup Of Sorrow')
# ('Faith No More', 'Album Of The Year', 'Alternative & Punk', 'Music', 'Naked In Front Of The Computer')
# ('Faith No More', 'Album Of The Year', 'Alternative & Punk', 'Music', 'Helpless')
# ('Faith No More', 'Album Of The Year', 'Alternative & Punk', 'Music', 'Mouth To Mouth')
# ('Faith No More', 'Album Of The Year', 'Alternative & Punk', 'Music', 'Ashes To Ashes')
# ('Faith No More', 'Album Of The Year', 'Alternative & Punk', 'Music', 'She Loves Me Not')
# ('Faith No More', 'Album Of The Year', 'Alternative & Punk', 'Music', 'Got That Feeling')
# ('Faith No More', 'Album Of The Year', 'Alternative & Punk', 'Music', 'Paths Of Glory')
# ('Faith No More', 'Album Of The Year', 'Alternative & Punk', 'Music', 'Home Sick Home')
# ('Faith No More', 'Album Of The Year', 'Alternative & Punk', 'Music', 'Pristina')
# ('Faith No More', 'Angel Dust', 'Alternative & Punk', 'Music', 'Land Of Sunshine')
# ('Faith No More', 'Angel Dust', 'Alternative & Punk', 'Music', 'Caffeine')
# ('Faith No More', 'Angel Dust', 'Alternative & Punk', 'Music', 'Midlife Crisis')
# ('Faith No More', 'Angel Dust', 'Alternative & Punk', 'Music', 'RV')
# ('Faith No More', 'Angel Dust', 'Alternative & Punk', 'Music', 'Smaller And Smaller')
# ('Faith No More', 'Angel Dust', 'Alternative & Punk', 'Music', "Everything's Ruined")
# ('Faith No More', 'Angel Dust', 'Alternative & Punk', 'Music', 'Malpractice')
# ('Faith No More', 'Angel Dust', 'Alternative & Punk', 'Music', 'Kindergarten')
# ('Faith No More', 'Angel Dust', 'Alternative & Punk', 'Music', 'Be Aggressive')
# ('Faith No More', 'Angel Dust', 'Alternative & Punk', 'Music', 'A Small Victory')
# ('Faith No More', 'Angel Dust', 'Alternative & Punk', 'Music', 'Crack Hitler')
# ('Faith No More', 'Angel Dust', 'Alternative & Punk', 'Music', 'Jizzlobber')
# ('Faith No More', 'Angel Dust', 'Alternative & Punk', 'Music', 'Midnight Cowboy')
# ('Faith No More', 'Angel Dust', 'Alternative & Punk', 'Music', 'Easy')
# ('Faith No More', 'The Real Thing', 'Alternative & Punk', 'Music', 'From Out Of Nowhere')
# ('Faith No More', 'The Real Thing', 'Alternative & Punk', 'Music', 'Epic')
# ('Faith No More', 'The Real Thing', 'Alternative & Punk', 'Music', 'Falling To Pieces')
# ('Faith No More', 'The Real Thing', 'Alternative & Punk', 'Music', "Surprise! You're Dead!")
# ('Faith No More', 'The Real Thing', 'Alternative & Punk', 'Music', 'Zombie Eaters')
# ('Faith No More', 'The Real Thing', 'Alternative & Punk', 'Music', 'The Real Thing')
# ('Faith No More', 'The Real Thing', 'Alternative & Punk', 'Music', 'Underwater Love')
# ('Faith No More', 'The Real Thing', 'Alternative & Punk', 'Music', 'The Morning After')
# ('Faith No More', 'The Real Thing', 'Alternative & Punk', 'Music', 'Woodpecker From Mars')
# ('Faith No More', 'The Real Thing', 'Alternative & Punk', 'Music', 'War Pigs')
# ('Faith No More', 'The Real Thing', 'Alternative & Punk', 'Music', 'Edge Of The World')
# ('Foo Fighters', 'One By One', 'Alternative & Punk', 'Music', 'All My Life')
# ('Foo Fighters', 'One By One', 'Alternative & Punk', 'Music', 'Low')
# ('Foo Fighters', 'One By One', 'Alternative & Punk', 'Music', 'Have It All')
# ('Foo Fighters', 'One By One', 'Alternative & Punk', 'Music', 'Times Like These')
# ('Foo Fighters', 'One By One', 'Alternative & Punk', 'Music', 'Disenchanted Lullaby')
# ('Foo Fighters', 'One By One', 'Alternative & Punk', 'Music', 'Tired Of You')
# ('Foo Fighters', 'One By One', 'Alternative & Punk', 'Music', 'Halo')
# ('Foo Fighters', 'One By One', 'Alternative & Punk', 'Music', 'Lonely As You')
# ('Foo Fighters', 'One By One', 'Alternative & Punk', 'Music', 'Overdrive')
# ('Foo Fighters', 'One By One', 'Alternative & Punk', 'Music', 'Burn Away')
# ('Foo Fighters', 'One By One', 'Alternative & Punk', 'Music', 'Come Back')
# ('Green Day', 'American Idiot', 'Alternative & Punk', 'Music', 'American Idiot')
# ('Green Day', 'American Idiot', 'Alternative & Punk', 'Music', "Jesus Of Suburbia / City Of The Damned / I Don't Care / Dearly Beloved / Tales Of Another Broken Home")
# ('Green Day', 'American Idiot', 'Alternative & Punk', 'Music', 'Holiday')
# ('Green Day', 'American Idiot', 'Alternative & Punk', 'Music', 'Boulevard Of Broken Dreams')
# ('Green Day', 'American Idiot', 'Alternative & Punk', 'Music', 'Are We The Waiting')
# ('Green Day', 'American Idiot', 'Alternative & Punk', 'Music', 'St. Jimmy')
# ('Green Day', 'American Idiot', 'Alternative & Punk', 'Music', 'Give Me Novacaine')
# ('Green Day', 'American Idiot', 'Alternative & Punk', 'Music', "She's A Rebel")
# ('Green Day', 'American Idiot', 'Alternative & Punk', 'Music', 'Extraordinary Girl')
# ('Green Day', 'American Idiot', 'Alternative & Punk', 'Music', 'Letterbomb')
# ('Green Day', 'American Idiot', 'Alternative & Punk', 'Music', 'Wake Me Up When September Ends')
# ('Green Day', 'American Idiot', 'Alternative & Punk', 'Music', "Homecoming / The Death Of St. Jimmy / East 12th St. / Nobody Likes You / Rock And Roll Girlfriend / We're Coming Home Again")
# ('Green Day', 'American Idiot', 'Alternative & Punk', 'Music', 'Whatsername')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Maria')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Poprocks And Coke')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Longview')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Welcome To Paradise')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Basket Case')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'When I Come Around')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'She')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'J.A.R. (Jason Andrew Relva)')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Geek Stink Breath')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Brain Stew')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Jaded')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Walking Contradiction')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Stuck With Me')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', "Hitchin' A Ride")
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Good Riddance (Time Of Your Life)')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Redundant')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Nice Guys Finish Last')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Minority')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Warning')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', 'Waiting')
# ('Green Day', 'International Superhits', 'Alternative & Punk', 'Music', "Macy's Day Parade")
# ('JET', 'Get Born', 'Alternative & Punk', 'Music', 'Last Chance')
# ('JET', 'Get Born', 'Alternative & Punk', 'Music', 'Are You Gonna Be My Girl')
# ('JET', 'Get Born', 'Alternative & Punk', 'Music', 'Rollover D.J.')
# ('JET', 'Get Born', 'Alternative & Punk', 'Music', "Look What You've Done")
# ('JET', 'Get Born', 'Alternative & Punk', 'Music', 'Get What You Need')
# ('JET', 'Get Born', 'Alternative & Punk', 'Music', 'Move On')
# ('JET', 'Get Born', 'Alternative & Punk', 'Music', 'Radio Song')
# ('JET', 'Get Born', 'Alternative & Punk', 'Music', 'Get Me Outta Here')
# ('JET', 'Get Born', 'Alternative & Punk', 'Music', 'Cold Hard Bitch')
# ('JET', 'Get Born', 'Alternative & Punk', 'Music', 'Come Around Again')
# ('JET', 'Get Born', 'Alternative & Punk', 'Music', 'Take It Or Leave It')
# ('JET', 'Get Born', 'Alternative & Punk', 'Music', 'Lazy Gun')
# ('JET', 'Get Born', 'Alternative & Punk', 'Music', 'Timothy')
# ('Os Mutantes', 'Minha História', 'Alternative & Punk', 'Music', 'Balada Do Louco')
# ('Os Mutantes', 'Minha História', 'Alternative & Punk', 'Music', 'Ando Meio Desligado')
# ('Os Mutantes', 'Minha História', 'Alternative & Punk', 'Music', 'Top Top')
# ('Os Mutantes', 'Minha História', 'Alternative & Punk', 'Music', 'Baby')
# ('Os Mutantes', 'Minha História', 'Alternative & Punk', 'Music', 'A E O Z')
# ('Os Mutantes', 'Minha História', 'Alternative & Punk', 'Music', 'Panis Et Circenses')
# ('Os Mutantes', 'Minha História', 'Alternative & Punk', 'Music', 'Chão De Estrelas')
# ('Os Mutantes', 'Minha História', 'Alternative & Punk', 'Music', 'Vida De Cachorro')
# ('Os Mutantes', 'Minha História', 'Alternative & Punk', 'Music', 'Bat Macumba')
# ('Os Mutantes', 'Minha História', 'Alternative & Punk', 'Music', 'Desculpe Babe')
# ('Os Mutantes', 'Minha História', 'Alternative & Punk', 'Music', 'Rita Lee')
# ('Os Mutantes', 'Minha História', 'Alternative & Punk', 'Music', 'Posso Perder Minha Mulher, Minha Mãe, Desde Que Eu Tenha O Rock And Roll')
# ('Os Mutantes', 'Minha História', 'Alternative & Punk', 'Music', 'Banho De Lua')
# ('Os Mutantes', 'Minha História', 'Alternative & Punk', 'Music', 'Meu Refrigerador Não Funciona')
# ('Pearl Jam', 'Pearl Jam', 'Alternative & Punk', 'Music', 'Life Wasted')
# ('Pearl Jam', 'Pearl Jam', 'Alternative & Punk', 'Music', 'World Wide Suicide')
# ('Pearl Jam', 'Pearl Jam', 'Alternative & Punk', 'Music', 'Comatose')
# ('Pearl Jam', 'Pearl Jam', 'Alternative & Punk', 'Music', 'Severed Hand')
# ('Pearl Jam', 'Pearl Jam', 'Alternative & Punk', 'Music', 'Marker In The Sand')
# ('Pearl Jam', 'Pearl Jam', 'Alternative & Punk', 'Music', 'Parachutes')
# ('Pearl Jam', 'Pearl Jam', 'Alternative & Punk', 'Music', 'Unemployable')
# ('Pearl Jam', 'Pearl Jam', 'Alternative & Punk', 'Music', 'Big Wave')
# ('Pearl Jam', 'Pearl Jam', 'Alternative & Punk', 'Music', 'Gone')
# ('Pearl Jam', 'Pearl Jam', 'Alternative & Punk', 'Music', 'Wasted Reprise')
# ('Pearl Jam', 'Pearl Jam', 'Alternative & Punk', 'Music', 'Army Reserve')
# ('Pearl Jam', 'Pearl Jam', 'Alternative & Punk', 'Music', 'Come Back')
# ('Pearl Jam', 'Pearl Jam', 'Alternative & Punk', 'Music', 'Inside Job')
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', 'Carnival Of Sorts')
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', 'Radio Free Aurope')
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', 'Perfect Circle')
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', 'Talk About The Passion')
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', 'So Central Rain')
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', "Don't Go Back To Rockville")
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', 'Pretty Persuasion')
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', 'Green Grow The Rushes')
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', "Can't Get There From Here")
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', 'Driver 8')
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', 'Fall On Me')
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', 'I Believe')
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', 'Cuyahoga')
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', 'The One I Love')
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', 'The Finest Worksong')
# ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 'Alternative & Punk', 'Music', "It's The End Of The World As We Know It (And I Feel Fine)")
# ('R.E.M.', 'Green', 'Alternative & Punk', 'Music', 'Pop Song 89')
# ('R.E.M.', 'Green', 'Alternative & Punk', 'Music', 'Get Up')
# ('R.E.M.', 'Green', 'Alternative & Punk', 'Music', 'You Are The Everything')
# ('R.E.M.', 'Green', 'Alternative & Punk', 'Music', 'Stand')
# ('R.E.M.', 'Green', 'Alternative & Punk', 'Music', 'World Leader Pretend')
# ('R.E.M.', 'Green', 'Alternative & Punk', 'Music', 'The Wrong Child')
# ('R.E.M.', 'Green', 'Alternative & Punk', 'Music', 'Orange Crush')
# ('R.E.M.', 'Green', 'Alternative & Punk', 'Music', 'Turn You Inside-Out')
# ('R.E.M.', 'Green', 'Alternative & Punk', 'Music', 'Hairshirt')
# ('R.E.M.', 'Green', 'Alternative & Punk', 'Music', 'I Remember California')
# ('R.E.M.', 'Green', 'Alternative & Punk', 'Music', 'Untitled')
# ('R.E.M. Feat. Kate Pearson', 'Out Of Time', 'Alternative & Punk', 'Music', 'Losing My Religion')
# ('R.E.M. Feat. Kate Pearson', 'Out Of Time', 'Alternative & Punk', 'Music', 'Low')
# ('R.E.M. Feat. Kate Pearson', 'Out Of Time', 'Alternative & Punk', 'Music', 'Near Wild Heaven')
# ('R.E.M. Feat. Kate Pearson', 'Out Of Time', 'Alternative & Punk', 'Music', 'Endgame')
# ('R.E.M. Feat. Kate Pearson', 'Out Of Time', 'Alternative & Punk', 'Music', 'Belong')
# ('R.E.M. Feat. Kate Pearson', 'Out Of Time', 'Alternative & Punk', 'Music', 'Half A World Away')
# ('R.E.M. Feat. Kate Pearson', 'Out Of Time', 'Alternative & Punk', 'Music', 'Texarkana')
# ('R.E.M. Feat. Kate Pearson', 'Out Of Time', 'Alternative & Punk', 'Music', 'Country Feedback')
# ('R.E.M. Feat. Kate Pearson', 'Out Of Time', 'Alternative & Punk', 'Music', 'Shiny Happy People')
# ('R.E.M. Feat. Kate Pearson', 'Out Of Time', 'Alternative & Punk', 'Music', 'Me In Honey')
# ('R.E.M. Feat. Kate Pearson', 'Out Of Time', 'Alternative & Punk', 'Music', 'Radio Song')
# ('Raimundos', 'Cesta Básica', 'Alternative & Punk', 'Music', 'Infeliz Natal')
# ('Raimundos', 'Cesta Básica', 'Alternative & Punk', 'Music', 'A Sua')
# ('Raimundos', 'Cesta Básica', 'Alternative & Punk', 'Music', 'Papeau Nuky Doe')
# ('Raimundos', 'Cesta Básica', 'Alternative & Punk', 'Music', 'Merry Christmas')
# ('Raimundos', 'Cesta Básica', 'Alternative & Punk', 'Music', 'Bodies')
# ('Raimundos', 'Cesta Básica', 'Alternative & Punk', 'Music', 'Puteiro Em João Pessoa')
# ('Raimundos', 'Cesta Básica', 'Alternative & Punk', 'Music', 'Esporrei Na Manivela')
# ('Raimundos', 'Cesta Básica', 'Alternative & Punk', 'Music', 'Bê-a-Bá')
# ('Raimundos', 'Cesta Básica', 'Alternative & Punk', 'Music', 'Cajueiro')
# ('Raimundos', 'Cesta Básica', 'Alternative & Punk', 'Music', 'Palhas Do Coqueiro')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'The Power Of Equality')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'If You Have To Ask')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'Breaking The Girl')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'Funky Monks')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'Suck My Kiss')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'I Could Have Lied')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'Mellowship Slinky In B Major')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'The Righteous & The Wicked')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'Give It Away')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'Blood Sugar Sex Magik')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'Under The Bridge')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'Naked In The Rain')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'Apache Rose Peacock')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'The Greeting Song')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'My Lovely Man')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', 'Sir Psycho Sexy')
# ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 'Alternative & Punk', 'Music', "They're Red Hot")
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', 'Lucky 13')
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', 'Aeroplane Flies High')
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', 'Because You Are')
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', 'Slow Dawn')
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', 'Believe')
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', 'My Mistake')
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', 'Marquis In Spades')
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', "Here's To The Atom Bomb")
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', 'Sparrow')
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', 'Waiting')
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', 'Saturnine')
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', 'Rock On')
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', 'Set The Ray To Jerry')
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', 'Winterlong')
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', 'Soot & Stars')
# ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 'Alternative & Punk', 'Music', 'Blissed & Gone')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'Siva')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'Rhinocerous')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'Drown')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'Cherub Rock')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'Today')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'Disarm')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'Landslide')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'Bullet With Butterfly Wings')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', '1979')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'Zero')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'Tonight, Tonight')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'Eye')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'Ava Adore')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'Perfect')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'The Everlasting Gaze')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'Stand Inside Your Love')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', 'Real Love')
# ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 'Alternative & Punk', 'Music', '[Untitled]')
# ('The Tea Party', 'Tangents', 'Alternative & Punk', 'Music', 'Walking Wounded')
# ('The Tea Party', 'Tangents', 'Alternative & Punk', 'Music', 'Temptation')
# ('The Tea Party', 'Tangents', 'Alternative & Punk', 'Music', 'The Messenger')
# ('The Tea Party', 'Tangents', 'Alternative & Punk', 'Music', 'Psychopomp')
# ('The Tea Party', 'Tangents', 'Alternative & Punk', 'Music', 'Sister Awake')
# ('The Tea Party', 'Tangents', 'Alternative & Punk', 'Music', 'The Bazaar')
# ('The Tea Party', 'Tangents', 'Alternative & Punk', 'Music', 'Save Me (Remix)')
# ('The Tea Party', 'Tangents', 'Alternative & Punk', 'Music', 'Fire In The Head')
# ('The Tea Party', 'Tangents', 'Alternative & Punk', 'Music', 'Release')
# ('The Tea Party', 'Tangents', 'Alternative & Punk', 'Music', 'Heaven Coming Down')
# ('The Tea Party', 'Tangents', 'Alternative & Punk', 'Music', 'The River (Remix)')
# ('The Tea Party', 'Tangents', 'Alternative & Punk', 'Music', 'Babylon')
# ('The Tea Party', 'Tangents', 'Alternative & Punk', 'Music', 'Waiting On A Sign')
# ('The Tea Party', 'Tangents', 'Alternative & Punk', 'Music', 'Life Line')
# ('The Tea Party', 'Tangents', 'Alternative & Punk', 'Music', 'Paint It Black')
# ('The Tea Party', 'Transmission', 'Alternative & Punk', 'Music', 'Temptation')
# ('The Tea Party', 'Transmission', 'Alternative & Punk', 'Music', 'Army Ants')
# ('The Tea Party', 'Transmission', 'Alternative & Punk', 'Music', 'Psychopomp')
# ('The Tea Party', 'Transmission', 'Alternative & Punk', 'Music', 'Gyroscope')
# ('The Tea Party', 'Transmission', 'Alternative & Punk', 'Music', 'Alarum')
# ('The Tea Party', 'Transmission', 'Alternative & Punk', 'Music', 'Release')
# ('The Tea Party', 'Transmission', 'Alternative & Punk', 'Music', 'Transmission')
# ('The Tea Party', 'Transmission', 'Alternative & Punk', 'Music', 'Babylon')
# ('The Tea Party', 'Transmission', 'Alternative & Punk', 'Music', 'Pulse')
# ('The Tea Party', 'Transmission', 'Alternative & Punk', 'Music', 'Emerald')
# ('The Tea Party', 'Transmission', 'Alternative & Punk', 'Music', 'Aftermath')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Comida')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Go Back')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Prá Dizer Adeus')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Família')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Os Cegos Do Castelo')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'O Pulso')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Marvin')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Nem 5 Minutos Guardados')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Flores')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Palavras')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Hereditário')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'A Melhor Forma')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Cabeça Dinossauro')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', '32 Dentes')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Bichos Escrotos (Vinheta)')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Não Vou Lutar')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Homem Primata (Vinheta)')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Homem Primata')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Polícia (Vinheta)')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Querem Meu Sangue')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Diversão')
# ('Titãs', 'Acústico', 'Alternative & Punk', 'Music', 'Televisão')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'Sonifera Ilha')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'Lugar Nenhum')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'Sua Impossivel Chance')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'Desordem')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'Não Vou Me Adaptar')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'Domingo')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'Amanhã Não Se Sabe')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'Caras Como Eu')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'Senhora E Senhor')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'Era Uma Vez')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'Miséria')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'Insensível')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'Eu E Ela')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'Toda Cor')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'É Preciso Saber Viver')
# ('Titãs', 'Volume Dois', 'Alternative & Punk', 'Music', 'Senhor Delegado/Eu Não Aguento')
# ('The Black Crowes', 'Live [Disc 1]', 'Blues', 'Music', 'Midnight From The Inside Out')
# ('The Black Crowes', 'Live [Disc 1]', 'Blues', 'Music', 'Sting Me')
# ('The Black Crowes', 'Live [Disc 1]', 'Blues', 'Music', 'Thick & Thin')
# ('The Black Crowes', 'Live [Disc 1]', 'Blues', 'Music', 'Greasy Grass River')
# ('The Black Crowes', 'Live [Disc 1]', 'Blues', 'Music', 'Sometimes Salvation')
# ('The Black Crowes', 'Live [Disc 1]', 'Blues', 'Music', 'Cursed Diamonds')
# ('The Black Crowes', 'Live [Disc 1]', 'Blues', 'Music', 'Miracle To Me')
# ('The Black Crowes', 'Live [Disc 1]', 'Blues', 'Music', 'Wiser Time')
# ('The Black Crowes', 'Live [Disc 1]', 'Blues', 'Music', 'Girl From A Pawnshop')
# ('The Black Crowes', 'Live [Disc 1]', 'Blues', 'Music', 'Cosmic Fiend')
# ('The Black Crowes', 'Live [Disc 2]', 'Blues', 'Music', 'Black Moon Creeping')
# ('The Black Crowes', 'Live [Disc 2]', 'Blues', 'Music', 'High Head Blues')
# ('The Black Crowes', 'Live [Disc 2]', 'Blues', 'Music', 'Title Song')
# ('The Black Crowes', 'Live [Disc 2]', 'Blues', 'Music', 'She Talks To Angels')
# ('The Black Crowes', 'Live [Disc 2]', 'Blues', 'Music', 'Twice As Hard')
# ('The Black Crowes', 'Live [Disc 2]', 'Blues', 'Music', "Lickin'")
# ('The Black Crowes', 'Live [Disc 2]', 'Blues', 'Music', 'Soul Singing')
# ('The Black Crowes', 'Live [Disc 2]', 'Blues', 'Music', 'Hard To Handle')
# ('The Black Crowes', 'Live [Disc 2]', 'Blues', 'Music', 'Remedy')
# ('Buddy Guy', 'The Best Of Buddy Guy - The Millenium Collection', 'Blues', 'Music', 'First Time I Met The Blues')
# ('Buddy Guy', 'The Best Of Buddy Guy - The Millenium Collection', 'Blues', 'Music', 'Let Me Love You Baby')
# ('Buddy Guy', 'The Best Of Buddy Guy - The Millenium Collection', 'Blues', 'Music', 'Stone Crazy')
# ('Buddy Guy', 'The Best Of Buddy Guy - The Millenium Collection', 'Blues', 'Music', 'Pretty Baby')
# ('Buddy Guy', 'The Best Of Buddy Guy - The Millenium Collection', 'Blues', 'Music', 'When My Left Eye Jumps')
# ('Buddy Guy', 'The Best Of Buddy Guy - The Millenium Collection', 'Blues', 'Music', 'Leave My Girl Alone')
# ('Buddy Guy', 'The Best Of Buddy Guy - The Millenium Collection', 'Blues', 'Music', 'She Suits Me To A Tee')
# ('Buddy Guy', 'The Best Of Buddy Guy - The Millenium Collection', 'Blues', 'Music', 'Keep It To Myself (Aka Keep It To Yourself)')
# ('Buddy Guy', 'The Best Of Buddy Guy - The Millenium Collection', 'Blues', 'Music', 'My Time After Awhile')
# ('Buddy Guy', 'The Best Of Buddy Guy - The Millenium Collection', 'Blues', 'Music', 'Too Many Ways (Alternate)')
# ('Buddy Guy', 'The Best Of Buddy Guy - The Millenium Collection', 'Blues', 'Music', "Talkin' 'Bout Women Obviously")
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'Layla')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'Badge')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'I Feel Free')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'Sunshine Of Your Love')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'Crossroads')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'Strange Brew')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'White Room')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'Bell Bottom Blues')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'Cocaine')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'I Shot The Sheriff')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'After Midnight')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'Swing Low Sweet Chariot')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'Lay Down Sally')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'Knockin On Heavens Door')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'Wonderful Tonight')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'Let It Grow')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', 'Promises')
# ('Eric Clapton', 'The Cream Of Clapton', 'Blues', 'Music', "I Can't Stand It")
# ('Eric Clapton', 'Unplugged', 'Blues', 'Music', 'Signe')
# ('Eric Clapton', 'Unplugged', 'Blues', 'Music', 'Before You Accuse Me')
# ('Eric Clapton', 'Unplugged', 'Blues', 'Music', 'Hey Hey')
# ('Eric Clapton', 'Unplugged', 'Blues', 'Music', 'Tears In Heaven')
# ('Eric Clapton', 'Unplugged', 'Blues', 'Music', 'Lonely Stranger')
# ('Eric Clapton', 'Unplugged', 'Blues', 'Music', "Nobody Knows You When You're Down & Out")
# ('Eric Clapton', 'Unplugged', 'Blues', 'Music', 'Layla')
# ('Eric Clapton', 'Unplugged', 'Blues', 'Music', 'Running On Faith')
# ('Eric Clapton', 'Unplugged', 'Blues', 'Music', "Walkin' Blues")
# ('Eric Clapton', 'Unplugged', 'Blues', 'Music', 'Alberta')
# ('Eric Clapton', 'Unplugged', 'Blues', 'Music', 'San Francisco Bay Blues')
# ('Eric Clapton', 'Unplugged', 'Blues', 'Music', 'Malted Milk')
# ('Eric Clapton', 'Unplugged', 'Blues', 'Music
academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 'Bach: Orchestral Suites Nos. 1 - 4', 'Classical', 'Music', 'Suite No. 3 in D, BWV 1068: III. Gavotte I & II')
# ('Academy of St. Martin in the Fields & Sir Neville Marriner', 'The World of Classical Favourites', 'Classical', 'Music', 'Fantasia On Greensleeves')
# ('Adrian Leaper & Doreen de Feis', 'Górecki: Symphony No. 3', 'Classical', 'Music', 'Symphony No. 3 Op. 36 for Orchestra and Soprano "Symfonia Piesni Zalosnych" \\ Lento E Largo - Tranquillissimo')
# ('Alberto Turco & Nova Schola Gregoriana', 'Adorate Deum: Gregorian Chant from the Proper of the Mass', 'Classical', 'Music', 'Intoitus: Adorate Deum')
# ('Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker', 'Vivaldi: The Four Seasons', 'Classical', 'Music', 'Concerto No. 1 in E Major, RV 269 "Spring": I. Allegro')
# ('Antal Doráti & London Symphony Orchestra', "Tchaikovsky: 1812 Festival Overture, Op.49, Capriccio Italien & Beethoven: Wellington's Victory", 'Classical', 'Music', "Wellington's Victory or the Battle Symphony, Op.91: 2. Symphony of Triumph")
# ('Barry Wordsworth & BBC Concert Orchestra', 'The Last Night of the Proms', 'Classical', 'Music', 'Nimrod (Adagio) from Variations On an Original Theme, Op. 36 "Enigma"')
# ('Berliner Philharmoniker & Hans Rosbaud', 'Sibelius: Finlandia', 'Classical', 'Music', 'Karelia Suite, Op.11: 2. Ballade (Tempo Di Menuetto)')
# ('Berliner Philharmoniker & Herbert Von Karajan', 'Grieg: Peer Gynt Suites & Sibelius: Pelléas et Mélisande', 'Classical', 'Music', 'Peer Gynt Suite No.1, Op.46: 1. Morning Mood')
# ('Berliner Philharmoniker & Herbert Von Karajan', 'Mozart: Symphonies Nos. 40 & 41', 'Classical', 'Music', 'Symphony No. 41 in C Major, K. 551, "Jupiter": IV. Molto allegro')
# ('Berliner Philharmoniker & Herbert Von Karajan', 'Prokofiev: Symphony No.5 & Stravinksy: Le Sacre Du Printemps', 'Classical', 'Music', 'Le Sacre Du Printemps: I.iv. Spring Rounds')
# ('Berliner Philharmoniker, Claudio Abbado & Sabine Meyer', 'Mozart: Wind Concertos', 'Classical', 'Music', 'Concerto for Clarinet in A Major, K. 622: II. Adagio')
# ('Boston Symphony Orchestra & Seiji Ozawa', 'Carmina Burana', 'Classical', 'Music', 'Carmina Burana: O Fortuna')
# ('Britten Sinfonia, Ivor Bolton & Lesley Garrett', 'A Soprano Inspired', 'Classical', 'Music', 'Ave Maria')
# ('C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', "Monteverdi: L'Orfeo", 'Classical', 'Music', "L'orfeo, Act 3, Sinfonia (Orchestra)")
# ("Charles Dutoit & L'Orchestre Symphonique de Montréal", 'The Ultimate Relexation Album', 'Classical', 'Music', '3 Gymnopédies: No.1 - Lent Et Grave, No.3 - Lent Et Douloureux')
# ('Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', 'Great Opera Choruses', 'Classical', 'Music', 'Nabucco: Chorus, "Va, Pensiero, Sull\'ali Dorate"')
# ('Chicago Symphony Orchestra & Fritz Reiner', 'Scheherazade', 'Classical', 'Music', "Scheherazade, Op. 35: I. The Sea and Sindbad's Ship")
# ('Choir Of Westminster Abbey & Simon Preston', 'Palestrina: Missa Papae Marcelli & Allegri: Miserere', 'Classical', 'Music', 'Missa Papae Marcelli: Kyrie')
# ('Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', 'Bizet: Carmen Highlights', 'Classical', 'Music', 'Carmen: Overture')
# ("Christopher O'Riley", 'SCRIABIN: Vers la flamme', 'Classical', 'Music', 'SCRIABIN: Prelude in B Major, Op. 11, No. 11')
# ('Edo de Waart & San Francisco Symphony', 'Adams, John: The Chairman Dances', 'Classical', 'Music', 'Two Fanfares for Orchestra: II. Short Ride in a Fast Machine')
# ('Emanuel Ax, Eugene Ormandy & Philadelphia Orchest
prokofiev: Symphony No.5 & Stravinksy: Le Sacre Du Printemps', 'Classical', 'Classical 101 - Deep Cuts', 'Le Sacre Du Printemps: I.iv. Spring Rounds')
# ("The King's Singers", 'English Renaissance', 'Classical', 'Classical 101 - Deep Cuts', 'Sing Joyfully')
# ('Martin Roscoe', 'Szymanowski: Piano Works, Vol. 1', 'Classical', 'Classical 101 - Deep Cuts', 'Metopes, Op. 29: Calypso')
# ('Göteborgs Symfoniker & Neeme Järvi', 'Nielsen: The Six Symphonies', 'Classical', 'Classical 101 - Deep Cuts', 'Symphony No. 2, Op. 16 -  "The Four Temperaments": II. Allegro Comodo e Flemmatico')
# ('Itzhak Perlman', "Great Recordings of the Century: Paganini's 24 Caprices", 'Classical', 'Classical 101 - Deep Cuts', '24 Caprices, Op. 1, No. 24, for Solo Violin, in A Minor')
# ('Michele Campanella', "Liszt - 12 Études D'Execution Transcendante", 'Classical', 'Classical 101 - Deep Cuts', 'Étude 1, In C Major - Preludio (Presto) - Liszt')
# ('Gerald Moore', 'Great Recordings of the Century - Shubert: Schwanengesang, 4 Lieder', 'Classical', 'Classical 101 - Deep Cuts', 'Erlkonig, D.328')
# ('Mela Tenenbaum, Pro Musica Prague & Richard Kapp', 'Locatelli: Concertos for Violin, Strings and Continuo, Vol. 3', 'Classical', 'Classical 101 - Deep Cuts', 'Concerto for Violin, Strings and Continuo in G Major, Op. 3, No. 9: I. Allegro')
# ('Eugene Ormandy', 'Respighi:Pines of Rome', 'Classical', 'Classical 101 - Deep Cuts', 'Pini Di Roma (Pinien Von Rom) \\ I Pini Della Via Appia')
# ('Emerson String Quartet', "Schubert: The Late String Quartets & String Quintet (3 CD's)", 'Classical', 'Classical 101 - Deep Cuts', 'String Quartet No. 12 in C Minor, D. 703 "Quartettsatz": II. Andante - Allegro assai')
# ('C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', "Monteverdi: L'Orfeo", 'Classical', 'Classical 101 - Deep Cuts', "L'orfeo, Act 3, Sinfonia (Orchestra)")
# ('Nash Ensemble', 'Mozart: Chamber Music', 'Classical', 'Classical 101 - Deep Cuts', 'Quintet for Horn, Violin, 2 Violas, and Cello in E Flat Major, K. 407/386c: III. Allegro')
# ('Philip Glass Ensemble', 'Koyaanisqatsi (Soundtrack from the Motion Picture)', 'Soundtrack', 'Classical 101 - Deep Cuts', 'Koyaanisqatsi')
# ('Ton Koopman', 'Bach: Toccata & Fugue in D Minor', 'Classical', 'Classical 101 - Next Steps', 'Toccata and Fugue in D Minor, BWV 565: I. Toccata')
# ('Sergei Prokofiev & Yuri Temirkanov', 'Prokofiev: Symphony No.1', 'Classical', 'Classical 101 - Next Steps', 'Symphony No.1 in D Major, Op.25 "Classical", Allegro Con Brio')
# ('Chicago Symphony Orchestra & Fritz Reiner', 'Scheherazade', 'Classical', 'Classical 101 - Next Steps', "Scheherazade, Op. 35: I. The Sea and Sindbad's Ship")
# ('Orchestra of The Age of Enlightenment', 'Bach: The Brandenburg Concertos', 'Classical', 'Classical 101 - Next Steps', 'Concerto No.2 in F Major, BWV1047, I. Allegro')
# ('Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', 'Chopin: Piano Concertos Nos. 1 & 2', 'Classical', 'Classical 101 - Next Steps', 'Concerto for Piano No. 2 in F Minor, Op. 21: II. Larghetto')
# ('James Levine', 'Mascagni: Cavalleria Rusticana', 'Classical', 'Classical 101 - Next Steps', 'Cavalleria Rusticana \\ Act \\ Intermezzo Sinfonico')
# ('Berliner Philharmoniker & Hans Rosbaud', 'Sibelius: Finlandia', 'Classical', 'Classical 101 - Next Steps', 'Karelia Suite, Op.11: 2. Ballade (Tempo Di Menuetto)')
# ('Maurizio Pollini', 'Beethoven Piano Sonatas: Moonlight & Pastorale', 'Classical', 'Classical 101 - Next Steps', 'Piano Sonata No. 14 in C Sharp Minor, Op. 27, No. 2, "Moonlight": I. Adagio sostenuto')
# ('Academy of St. Martin in the Fields & Sir Neville Marriner', 'The World of Classical Favourites', 'Classical', 'Classical 101 - Next Steps', 'Fantasia On Greensleeves')
# ('Gustav Mahler', 'Great Recordings of the Century - Mahler: Das Lied von der Erde', 'Classical', 'Classical 101 - Next Steps', 'Das Lied Von Der Erde, Von Der Jugend')
# ('Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', 'Elgar: Cello Concerto & Vaughan Williams: Fantasias', 'Classical', 'Classical 101 - Next Steps', 'Concerto for Cello and Orchestra in E minor, Op. 85: I. Adagio - Moderato')
# ('Edo de Waart & San Francisco Symphony', 'Adams, John: The Chairman Dances', 'Classical', 'Classical 101 - Next Steps', 'Two Fanfares for Orchestra: II. Short Ride in a Fast Machine')
# ('Antal Doráti & London Symphony Orchestra', "Tchaikovsky: 1812 Festival Overture, Op.49, Capriccio Italien & Beethoven: Wellington's Victory", 'Classical', 'Classical 101 - Next Steps', "Wellington's Victory or the Battle Symphony, Op.91: 2. Symphony of Triumph")
# ('Choir Of Westminster Abbey & Simon Preston', 'Palestrina: Missa Papae Marcelli & Allegri: Miserere', 'Classical', 'Classical 101 - Next Steps', 'Missa Papae Marcelli: Kyrie')
# ('Michael Tilson Thomas & San Francisco Symphony', 'Prokofiev: Romeo & Juliet', 'Classical', 'Classical 101 - Next Steps', 'Romeo et Juliette: No. 11 - Danse des Chevaliers')
# ('Eugene Ormandy', 'Strauss: Waltzes', 'Classical', 'Classical 101 - Next Steps', 'On the Beautiful Blue Danube')
# ('Michael Tilson Thomas & San Francisco Symphony', 'Berlioz: Symphonie Fantastique', 'Classical', 'Classical 101 - Next Steps', "Symphonie Fantastique, Op. 14: V. Songe d'une nuit du sabbat")
# ('Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', 'Bizet: Carmen Highlights', 'Classical', 'Classical 101 - Next Steps', 'Carmen: Overture')
# ("The King's Singers", 'English Renaissance', 'Classical', 'Classical 101 - Next Steps', 'Lamentations of Jeremiah, First Set \\ Incipit Lamentatio')
# ('English Concert & Trevor Pinnock', 'Handel: Music for the Royal Fireworks (Original Version 1749)', 'Classical', 'Classical 101 - Next Steps', 'Music for the Royal Fireworks, HWV351 (1749): La Réjouissance')
# ('Berliner Philharmoniker & Herbert Von Karajan', 'Grieg: Peer Gynt Suites & Sibelius: Pelléas et Mélis
('Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', 'Great Opera Choruses', 'Classical', 'Classical 101 - The Basics', 'Nabucco: Chorus, "Va, Pensiero, Sull\'ali Dorate"')
# ('Sir Georg Solti & Wiener Philharmoniker', 'Wagner: Favourite Overtures', 'Classical', 'Classical 101 - The Basics', 'Die Walküre: The Ride of the Valkyries')
# ('Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 'Fauré: Requiem, Ravel: Pavane & Others', 'Classical', 'Classical 101 - The Basics', 'Requiem, Op.48: 4. Pie Jesu')
# ('London Symphony Orchestra & Sir Charles Mackerras', 'Tchaikovsky: The Nutcracker', 'Classical', 'Classical 101 - The Basics', 'The Nutcracker, Op. 71a, Act II: Scene 14: Pas de deux: Dance of the Prince & the Sugar-Plum Fairy')
# ('Barry Wordsworth & BBC Concert Orchestra', 'The Last Night of the Proms', 'Classical', 'Classical 101 - The Basics', 'Nimrod (Adagio) from Variations On an Original Theme, Op. 36 "Enigma"')
# ('Herbert Von Karajan, Mirella Freni & Wiener Philharmoniker', 'Puccini: Madama Butterfly - Highlights', 'Classical', 'Classical 101 - The Basics', 'Madama Butterfly: Un Bel Dì Vedremo')
# ('Eugene Ormandy', 'Holst: The Planets, Op. 32 & Vaughan Williams: Fantasies', 'Classical', 'Classical 101 - The Basics', 'Jupiter, the Bringer of Jollity')
# ('Luciano Pavarotti', "Pavarotti's Opera Made Easy", 'Classical', 'Classical 101 - The Basics', 'Turandot, Act III, Nessun dorma!')
# ('Leonard Bernstein & New York Philharmonic', "Great Performances - Barber's Adagio and Other Romantic Favorites for Strings", 'Classical', 'Classical 101 - The Basics', 'Adagio for Strings from the String Quartet, Op. 11')
# ('Boston Symphony Orchestra & Seiji Ozawa', 'Carmina Burana', 'Classical', 'Classical 101 - The Basics', 'Carmina Burana: O Fortuna')
# ('Aaron Copland & London Symphony Orchestra', 'A Copland Celebration, Vol. I', 'Classical', 'Classical 101 - The Basics', 'Fanfare for the Common Man')
# ('Temple of the Dog', 'Temple of the Dog', 'Alternative', 'Grunge', 'Hunger Strike')
# ('Alice In Chains', 'Facelift', 'Rock', 'Grunge', 'Man In The Box')
# ('Pearl Jam', 'Ten', 'Rock', 'Grunge', 'Evenflow')
# ('Pearl Jam', 'Ten', 'Rock', 'Grunge', 'Alive')
# ('Pearl Jam', 'Ten', 'Rock', 'Grunge', 'Jeremy')
# ('Pearl Jam', 'Vs.', 'Rock', 'Grunge', 'Daughter')
# ('Soundgarden', 'A-Sides', 'Rock', 'Grunge', 'Outshined')
# ('Soundgarden', 'A-Sides', 'Rock', 'Grunge', 'Black Hole Sun')
# ('Stone Temple Pilots', 'Core', 'Rock', 'Grunge', 'Plush')
# ('Nirvana', 'Nevermind', 'Rock', 'Grunge', 'Smells Like Teen Spirit')
# ('Nirvana', 'Nevermind', 'Rock', 'Grunge', 'In Bloom')
# ('Nirvana', 'Nevermind', 'Rock', 'Grunge', 'Come As You Are')
# ('Nirvana', 'Nevermind', 'Rock', 'Grunge', 'Lithium')
# ('Nirvana', 'Nevermind', 'Rock', 'Grunge', 'Drain You')
# ('Nirvana', 'Nevermind', 'Rock', 'Grunge', 'On A Plain')
# ('AC/DC', 'For Those About To Rock We Salute You', 'Rock', 'Heavy Metal Classic', 'For Those About To Rock (We Salute You)')
# ('Accept', 'Balls to the Wall', 'Rock', 'Heavy Metal Classic', 'Balls to the Wall')
# ('Accept', 'Restless and Wild', 'Rock', 'Heavy Metal Classic', 'Fast As a Shark')
# ('Accept', 'Restless and Wild', 'Rock', 'Heavy Metal Classic', 'Restless and Wild')
# ('Accept', 'Restless and Wild', 'Rock', 'Heavy Metal Classic', 'Princess of the Dawn')
# ('Black Sabbath', 'Black Sabbath', 'Metal', 'Heavy Metal Classic', 'N.I.B.')
# ('Black Sabbath', 'Black Sabbath Vol. 4 (Remaster)', 'Metal', 'Heavy Metal Classic', 'Supernaut')
# ('Iron Maiden', 'Killers', 'Heavy Metal', 'Heavy Metal Classic', 'Wrathchild')
# ('Iron Maiden', 'Killers', 'Heavy Metal', 'Heavy Metal Classic', 'Killers')
# ('Iron Maiden', 'The Number of The Beast', 'Metal', 'Heavy Metal Classic', 'Run to the Hills')
# ('Iron Maiden', 'Piece Of Mind', 'Metal', 'Heavy Metal Classic', 'Where Eagles Dare')
# ('Iron Maiden', 'Powerslave', 'Metal', 'Heavy Metal Classic', '2 Minutes To Midnight')
# ('Iron Maiden', 'Somewhere in Time', 'Metal', 'Heavy Metal Classic', 'Wasted Years')
# ('Metallica', 'Black Album', 'Metal', 'Heavy Metal Classic', 'Enter Sandman')
# ('Metallica', "Kill 'Em All", 'Metal', 'Heavy Metal Classic', 'The Four Horsemen')
# ('Metallica', "Kill 'Em All", 'Metal', 'Heavy Metal Classic', 'Seek & Destroy')
# ('Metallica', 'Master Of Puppets', 'Metal', 'Heavy Metal Classic', 'Master Of Puppets')
# ('Metallica', 'Ride The Lightning', 'Metal', 'Heavy Metal Classic', 'For Whom The Bell Tolls')
# ('Metallica', 'Ride The Lightning', 'Metal', 'Heavy Metal Classic', 'Creeping Death')
# ('Mötley Crüe', 'Motley Crue Greatest Hits', 'Metal', 'Heavy Metal Classic', 'Looks That Kill')
# ('Motörhead', 'Ace Of Spades', 'Metal', 'Heavy Metal Classic', 'Ace Of Spades')
# ('Motörhead', 'Ace Of Spades', 'Metal', 'Heavy Metal Classic', 'Live To Win')
# ('Ozzy Osbourne', 'Blizzard of Ozz', 'Rock', 'Heavy Metal Classic', "I Don't Know")
# ('Ozzy Osbourne', 'Blizzard of Ozz', 'Rock', 'Heavy Metal Classic', 'Crazy Train')
# ('Ozzy Osbourne', 'Diary of a Madman (Remastered)', 'Rock', 'Heavy Metal Classic', 'Flying High Again')
# ('Scorpions', '20th Century Masters - The Millennium Collection: The Best of Scorpions', 'Rock', 'Heavy Metal Classic', 'The Zoo')
# ('Miles Davis', 'The Essential Miles Davis [Disc 1]', 'Jazz', 'On-The-Go 1', "Now's The Time")

# %%
df = pd.read_sql_query("""
                SELECT ar.Name AS Artist, al.Title AS Album, g.Name AS Genre, p.Name AS Playlist, t.Name AS Track
                FROM Artist ar
                INNER JOIN Album al ON ar.ArtistId == al.ArtistId
                INNER JOIN Track t ON t.AlbumId == al.AlbumId
                INNER JOIN Genre g ON g.GenreId == t.GenreId
                INNER JOIN PlaylistTrack pt ON t.TrackId == pt.TrackId
                INNER JOIN Playlist p ON p.PlaylistId == PT.PlaylistId
               """,conn)
df
# Out:
#              Artist                                              Album  \
# 0        Audioslave                                        Revelations
# 1        Audioslave                                        Revelations
# 2        Audioslave                                        Revelations
# 3        Audioslave                                        Revelations
# 4        Audioslave                                        Revelations
# 5        Audioslave                                        Revelations
# 6        Audioslave                                        Revelations
# 7        Audioslave                                        Revelations
# 8        Audioslave                                        Revelations
# 9        Audioslave                                        Revelations
# 10       Audioslave                                        Revelations
# 11       Audioslave                                        Revelations
# 12       Audioslave                                        Revelations
# 13       Audioslave                                        Revelations
# 14             Cake                         Cake: B-Sides and Rarities
# 15         Calexico              Carried to Dust (Bonus Track Version)
# 16    Chris Cornell                                           Carry On
# 17    Chris Cornell                                           Carry On
# 18    Chris Cornell                                           Carry On
# 19    Chris Cornell                                           Carry On
# 20    Chris Cornell                                           Carry On
# 21    Chris Cornell                                           Carry On
# 22    Chris Cornell                                           Carry On
# 23    Chris Cornell                                           Carry On
# 24    Chris Cornell                                           Carry On
# 25    Chris Cornell                                           Carry On
# 26    Chris Cornell                                           Carry On
# 27    Chris Cornell                                           Carry On
# 28    Chris Cornell                                           Carry On
# 29    Chris Cornell                                           Carry On
# ...             ...                                                ...
# 8685        Nirvana                                          Nevermind
# 8686        Nirvana                                          Nevermind
# 8687        Nirvana                                          Nevermind
# 8688          AC/DC              For Those About To Rock We Salute You
# 8689         Accept                                  Balls to the Wall
# 8690         Accept                                  Restless and Wild
# 8691         Accept                                  Restless and Wild
# 8692         Accept                                  Restless and Wild
# 8693  Black Sabbath                                      Black Sabbath
# 8694  Black Sabbath                    Black Sabbath Vol. 4 (Remaster)
# 8695    Iron Maiden                                            Killers
# 8696    Iron Maiden                                            Killers
# 8697    Iron Maiden                            The Number of The Beast
# 8698    Iron Maiden                                      Piece Of Mind
# 8699    Iron Maiden                                         Powerslave
# 8700    Iron Maiden                                  Somewhere in Time
# 8701      Metallica                                        Black Album
# 8702      Metallica                                       Kill 'Em All
# 8703      Metallica                                       Kill 'Em All
# 8704      Metallica                                  Master Of Puppets
# 8705      Metallica                                 Ride The Lightning
# 8706      Metallica                                 Ride The Lightning
# 8707    Mötley Crüe                          Motley Crue Greatest Hits
# 8708      Motörhead                                      Ace Of Spades
# 8709      Motörhead                                      Ace Of Spades
# 8710  Ozzy Osbourne                                    Blizzard of Ozz
# 8711  Ozzy Osbourne                                    Blizzard of Ozz
# 8712  Ozzy Osbourne                     Diary of a Madman (Remastered)
# 8713      Scorpions  20th Century Masters - The Millennium Collecti...
# 8714    Miles Davis                 The Essential Miles Davis [Disc 1]
# 8691                                 Restless and Wild
# 8692                              Princess of the Dawn
# 8693                                            N.I.B.
# 8694                                         Supernaut
# 8695                                        Wrathchild
# 8696                                           Killers
# 8697                                  Run to the Hills
# 8698                                 Where Eagles Dare
# 8699                             2 Minutes To Midnight
# 8700                                      Wasted Years
# 8701                                     Enter Sandman
# 8702                                 The Four Horsemen
# 8703                                    Seek & Destroy
# 8704                                 Master Of Puppets
# 8705                           For Whom The Bell Tolls
# 8706                                    Creeping Death
# 8707                                   Looks That Kill
# 8708                                     Ace Of Spades
# 8709                                       Live To Win
# 8710                                      I Don't Know
# 8711                                       Crazy Train
# 8712                                 Flying High Again
# 8713                                           The Zoo
# 8714                                    Now's The Time
#
# [8715 rows x 5 columns]

# %% [markdown]
# ## (b)

# %%
# Use sql query to find artists who have more than one album
artist = pd.read_sql_query("""
                SELECT Name, Cnt
                FROM
                   (
                   SELECT Name,COUNT(AlbumId) AS Cnt
                       FROM 
                       (
                       SELECT Artist.Name, Artist.ArtistId,Album.AlbumId FROM Artist
                       INNER JOIN Album USING (ArtistId)
                       )
                   GROUP BY Name
                   )
               WHERE Cnt > 1
               """,conn)
artist = list(artist['Name'])
print("Artists who have more than one ablum:")
print(artist)
df = df[df['Artist'].isin(artist)]
df
# Out:
# Artists who have more than one ablum:
# ['AC/DC', 'Accept', 'Amy Winehouse', 'Antônio Carlos Jobim', 'Audioslave', 'Battlestar Galactica', 'Berliner Philharmoniker & Herbert Von Karajan', 'Black Label Society', 'Black Sabbath', 'Caetano Veloso', 'Chico Science & Nação Zumbi', 'Cidade Negra', 'Creedence Clearwater Revival', 'Cássia Eller', 'Deep Purple', 'Djavan', 'English Concert & Trevor Pinnock', 'Eric Clapton', 'Eugene Ormandy', 'Faith No More', 'Foo Fighters', 'Gilberto Gil', 'Green Day', "Guns N' Roses", 'Iron Maiden', 'Jamiroquai', 'Kiss', 'Led Zeppelin', 'Legião Urbana', 'Lost', 'Lulu Santos', 'Metallica', 'Michael Tilson Thomas & San Francisco Symphony', 'Miles Davis', 'Milton Nascimento', 'Nirvana', 'Os Paralamas Do Sucesso', 'Ozzy Osbourne', 'Pearl Jam', 'Queen', 'R.E.M.', 'Red Hot Chili Peppers', 'Santana', 'Skank', 'Smashing Pumpkins', 'Spyro Gyra', 'The Black Crowes', 'The Cult', 'The Office', 'The Rolling Stones', 'The Tea Party', 'Tim Maia', 'Titãs', 'U2', 'Van Halen', 'Various Artists']
#              Artist                                  Album  \
# 0        Audioslave                            Revelations
# 1        Audioslave                            Revelations
# 2        Audioslave                            Revelations
# 3        Audioslave                            Revelations
# 4        Audioslave                            Revelations
# 5        Audioslave                            Revelations
# 6        Audioslave                            Revelations
# 7        Audioslave                            Revelations
# 8        Audioslave                            Revelations
# 9        Audioslave                            Revelations
# 10       Audioslave                            Revelations
# 11       Audioslave                            Revelations
# 12       Audioslave                            Revelations
# 13       Audioslave                            Revelations
# 40       Audioslave                           Out Of Exile
# 41       Audioslave                           Out Of Exile
# 8690                Rock  Heavy Metal Classic
# 8691                Rock  Heavy Metal Classic
# 8692                Rock  Heavy Metal Classic
# 8693               Metal  Heavy Metal Classic
# 8694               Metal  Heavy Metal Classic
# 8695         Heavy Metal  Heavy Metal Classic
# 8696         Heavy Metal  Heavy Metal Classic
# 8697               Metal  Heavy Metal Classic
# 8698               Metal  Heavy Metal Classic
# 8699               Metal  Heavy Metal Classic
# 8700               Metal  Heavy Metal Classic
# 8701               Metal  Heavy Metal Classic
# 8702               Metal  Heavy Metal Classic
# 8703               Metal  Heavy Metal Classic
# 8704               Metal  Heavy Metal Classic
# 8705               Metal  Heavy Metal Classic
# 8706               Metal  Heavy Metal Classic
# 8710                Rock  Heavy Metal Classic
# 8711                Rock  Heavy Metal Classic
# 8712                Rock  Heavy Metal Classic
# 8714                Jazz          On-The-Go 1
#
#                                                  Track
# 0       Band Members Discuss Tracks from "Revelations"
# 1                                          Revelations
# 2                                     One and the Same
# 3                                       Sound of a Gun
# 4                                        Until We Fall
# 5                                        Original Fire
# 6                                          Broken City
# 7                                             Somedays
# 8                              Shape of Things to Come
# 9                              Jewel of the Summertime
# 10                                          Wide Awake
# 11                     Nothing Left to Say But Goodbye
# 12                                                Moth
# 13    Show Me How to Live (Live at the Quart Festival)
# 40                                  Your Time Has Come
# 41                                        Out Of Exile
# 42                                         Be Yourself
# 43                                   Doesn't Remind Me
# 44                                     Drown Me Slowly
# 45                                       Heaven's Dead
# 46                                            The Worm
# 47                                       Man Or Animal
# 48                               Yesterday To Tomorrow
# 49                                           Dandelion
# 50                                             #1 Zero
# 51                                           The Curse
# 87                                           Collision
# 88                                         Stripsearch
# 89                                  Last Cup Of Sorrow
# 90                      Naked In Front Of The Computer
# ...                                                ...
# 8678                                          Daughter
# 8682                           Smells Like Teen Spirit
# 8683                                          In Bloom
# 8684                                   Come As You Are
# 8685                                           Lithium
# 8686                                         Drain You
# 8687                                        On A Plain
# 8688           For Those About To Rock (We Salute You)
# 8689                                 Balls to the Wall
# 8690                                   Fast As a Shark
# 8691                                 Restless and Wild
# 8692                              Princess of the Dawn
# 8693                                            N.I.B.
# 8694                                         Supernaut
# 8695                                        Wrathchild
# 8696                                           Killers
# 8697                                  Run to the Hills
# 8698                                 Where Eagles Dare
# 8699                             2 Minutes To Midnight
# 8700                                      Wasted Years
# 8701                                     Enter Sandman
# 8702                                 The Four Horsemen
# 8703                                    Seek & Destroy
# 8704                                 Master Of Puppets
# 8705                           For Whom The Bell Tolls
# 8706                                    Creeping Death
# 8710                                      I Don't Know
# 8711                                       Crazy Train
# 8712                                 Flying High Again
# 8714                                    Now's The Time
#
# [5697 rows x 5 columns]

# %% [markdown]
# ## (c)

# %%
genre = pd.read_sql_query("""SELECT g.Name,COUNT(*) 
                            FROM Track t, Genre g ON g.GenreID == t.GenreID 
                            GROUP BY g.GenreID ORDER BY COUNT(*) DESC""",conn)
genre = list(genre['Name'])[:7]
genre
# Out:
# ['Rock', 'Latin', 'Metal', 'Alternative & Punk', 'Jazz', 'TV Shows', 'Blues']

# %%
artists = pd.unique(df['Artist'])
genre = pd.read_sql_query("""SELECT g.Name,COUNT(*) 
                            FROM Track t, Genre g 
                            ON g.GenreID == t.GenreID 
                            GROUP BY g.GenreID 
                            ORDER BY COUNT(*) DESC
                            """,conn)
genre = list(genre['Name'])[:7]
col = genre
col.insert(0,'Artist')
col.extend(['AlbumsNumber','TracksNumber','PlaylistsNumber'])
print(col)
matrix = pd.DataFrame(columns = col)
for artist in artists:
    row = []
    row.append(artist)
    temp = df[df['Artist'] == artist]
    albumNum = temp['Album'].nunique()
    trackNum = temp['Track'].nunique()
    playlistNum = temp['Playlist'].nunique()
    temp = temp.drop_duplicates(subset = ['Track'])
    for g in genre[1:8]:
        if g not in list(temp['Genre']):
            row.append(0)
        else:
            cnt = temp[temp['Genre'] == g].shape[0]
            row.append(cnt)
    row.append(albumNum)
    row.append(trackNum)
    row.append(playlistNum)
    matrix = matrix.append(pd.Series(row, index = col), ignore_index=True)

matrix
# Out:
# ['Artist', 'Rock', 'Latin', 'Metal', 'Alternative & Punk', 'Jazz', 'TV Shows', 'Blues', 'AlbumsNumber', 'TracksNumber', 'PlaylistsNumber']
#                                             Artist Rock Latin Metal  \
# 0                                       Audioslave   14     0     0
# 1                                    Faith No More   15     0     0
# 2                                     Foo Fighters   33     0     0
# 3                                        Green Day    0     0     0
# 4                                        Pearl Jam   50     0     0
# 5                                           R.E.M.   14     0     0
# 6                            Red Hot Chili Peppers   31     0     0
# 7                                Smashing Pumpkins    0     0     0
# 8                                    The Tea Party    0     0     0
# 9                                            Titãs    0     0     0
# 10                                The Black Crowes    0     0     0
# 11                                    Eric Clapton    0    16     0
# 12                                     Iron Maiden   42     0    72
# 13   Berliner Philharmoniker & Herbert Von Karajan    0     0     0
# 14                English Concert & Trevor Pinnock    0     0     0
# 15                                  Eugene Ormandy    0     0     0
# 16  Michael Tilson Thomas & San Francisco Symphony    0     0     0
# 17                                      Jamiroquai   10     0     0
# 18                            Antônio Carlos Jobim    0    16     0
# 19                                    Gilberto Gil    0    15     0
# 20                                     Miles Davis    0     0     0
# 21                                      Spyro Gyra    0     0     0
# 22                                  Caetano Veloso    0    21     0
# 23                                    Cássia Eller    0    30     0
# 24                     Chico Science & Nação Zumbi    0    35     0
# 25                                          Djavan    0    24     0
# 26                                   Legião Urbana    0    30     0
# 27                                     Lulu Santos    0    28     0
# 28                               Milton Nascimento    0    26     0
# 29                         Os Paralamas Do Sucesso    0    45     0
# 30                                        Tim Maia    0    30     0
# 31                                 Various Artists    0    28     0
# 32                             Black Label Society    0     0    18
# 33                                   Black Sabbath    0     0    17
# 34                                   Guns N' Roses   28     0    14
# 35                                       Metallica    0     0   112
# 36                                   Ozzy Osbourne   14     0    14
# 37                                              U2  103     0     0
# 38                                   Amy Winehouse    0     0     0
# 39                                    Cidade Negra    0     0     0
# 40                                           AC/DC   18     0     0
# 41                                          Accept    4     0     0


# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
import matplotlib

ks=[2,4,6,8,10]
inerias = []
matrix_n = matrix.drop(['Artist'], axis = 1)
for k in ks:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(matrix_n)
    y_kmeans = kmeans.predict(matrix_n)
    ineria = kmeans.inertia_
    inerias.append([k, ineria])
    print(ineria)
    
inerias = np.array(inerias)
plt.scatter(inerias[:, 0], inerias[:, 1])   
plt.plot(inerias[:, 0], inerias[:, 1])  
plt.xlabel("k")
plt.ylabel("inertia")
plt.title("inertia - k")
# Out:
# 67803.79607843136
# 36988.67647058823
# 22804.80586080586
# 14555.621565934067
# 10429.565476190477
# Text(0.5, 1.0, 'inertia - k')

# %% [markdown]
# Choose k = 4.
# From the plot, we can see that k = 4 is at the “elbow” of the plot. Therefore, it provides a good tradeoff between accuracy (low value of inertia) and complexity (small value of k), which makes it the ideal number of k.

# %% [markdown]
# ## (e)

# %%
from sklearn.metrics import pairwise_distances_argmin_min

kmeans = KMeans(n_clusters=4)
km = kmeans.fit(matrix_n)
closest, _ = pairwise_distances_argmin_min(km.cluster_centers_, matrix_n)
print("ID:" + str(closest))
print("Artist:\n")
ind = 1
for i in closest:
    print("Centroid %d\n"%ind)
    print(matrix['Artist'][i])
    print(matrix.iloc[i,:])
    print("\n")
    ind += 1
# Out:
# ID:[ 0 19 46 12]
# Artist:
#
# Centroid 1
#
# Audioslave
# Artist                Audioslave
# Rock                          14
# Latin                          0
# Metal                          0
# Alternative & Punk            12
# Jazz                           0
# TV Shows                       0
# Blues                          0
# AlbumsNumber                   3
# TracksNumber                  40
# PlaylistsNumber                2
# Name: 0, dtype: object
#
#
# Centroid 2
#
# Gilberto Gil
# Artist                Gilberto Gil
# Rock                             0
# Latin                           15
# Metal                            0
# Alternative & Punk               0
# Jazz                             3
# TV Shows                         0
# Blues                            0
# AlbumsNumber                     3
# TracksNumber                    32
# PlaylistsNumber                  3
# Name: 19, dtype: object
#
#
# Centroid 3
#
# Led Zeppelin
# Artist                Led Zeppelin
# Rock                            91
# Latin                            0
# Metal                            0
# Alternative & Punk               0
# Jazz                             0
# TV Shows                         0
# Blues                            0
# AlbumsNumber                    14
# TracksNumber                    91
# PlaylistsNumber                  2
# Name: 46, dtype: object
#
#
# Centroid 4
#
# Iron Maiden
# Artist                Iron Maiden
# Rock                           42
# Latin                           0
# Metal                          72
# Alternative & Punk              0
# Jazz                            0
# TV Shows                        0
# Blues                           9
# AlbumsNumber                   21
# TracksNumber                  150
# PlaylistsNumber                 3
# Name: 12, dtype: object

# %% [markdown]
# I think the data is clustered highly because of genre. From above we can see that each cluster centroid has must of their songs in different genre. For example, Led Zeppelin's songs are all rock songs, while Gilberto Gil's are about Latin. Iron Maiden and Foo Fighters's songs are more comprehensive. But we can still clear see that their focusing genre are quite different. Thus, I think they are mainly clstered by genre.
